# %% [markdown]
# # Machine Learning Assignment - 07

# %% [markdown]
# # 1. What is the definition of a target function? In the sense of a real-life example, express the target function. How is a target function's fitness assessed?

# %% [markdown]
# A target function is a mathematical function that maps inputs to outputs and is used in supervised machine learning as a criterion for making predictions. The goal of the learning algorithm is to find the values of the parameters that optimize the target function, so that the predicted outputs are as close as possible to the actual outputs. The target function is also called a loss function or objective function and measures the quality of the predictions made by the model.
#
#
#
# A real-life example of a target function could be in the context of a regression problem, where the target variable is a continuous value. In this case, the target function could be the mean squared error (MSE) between the predicted values and the actual values. The target function in this case is:
#
# MSE = 1/n * Σ(y_actual - y_predicted)^2
#
# where n is the number of samples, y_actual is the actual target value, and y_predicted is the predicted target value.
#
# The fitness of a target function is assessed by measuring how well it fits the data. In the case of the MSE example, a lower value of MSE indicates a better fit and a better prediction. The goal of machine learning algorithms is to find the optimal model parameters that minimize the target function and result in the best fit and prediction for the data.
#
#
# In machine learning, the target function is often used in supervised learning algorithms where the goal is to minimize the error between the predicted output and the actual output. The fitness of the target function is assessed by evaluating the accuracy of the model's predictions on a test set of data.

# %% [markdown]
# # 2. What are predictive models, and how do they work? What are descriptive types, and how do you use them? Examples of both types of models should be provided. Distinguish between these two forms of models.

# %% [markdown]
# Predictive models are statistical or machine learning models that are used to make predictions about future outcomes based on past data. Predictive models work by learning patterns and relationships in the training data, which are then used to make predictions about unseen data.
#
# There are various types of predictive models, including linear regression, logistic regression, decision trees, random forests, and neural networks. The choice of model depends on the type of problem being solved and the nature of the data.
#
# The basic process for building a predictive model involves selecting a model type, training the model on a dataset, evaluating its performance, and fine-tuning the model as needed. During training, the model learns the relationships between the input variables and the target variable by adjusting its internal parameters. The model is then evaluated on a separate test set of data to determine its accuracy.
#
# Once the model has been trained and its performance has been evaluated, it can be used to make predictions on new, unseen data. The quality of the predictions depends on the quality of the training data and the ability of the model to generalize to new data.
#
#
# DESCRIPTIVE
#
# Descriptive statistics are a set of techniques used to summarize and describe the main features of a dataset. They provide a concise summary of the data and give insights into the distribution, central tendency, and variability of the variables of interest.
#
# The most common descriptive statistics include measures of central tendency such as mean, median, and mode, measures of variability such as range, variance, and standard deviation, and measures of distribution such as histograms and box plots.
#
# These techniques can be used to understand the underlying patterns in the data and identify any outliers or anomalies. This information can be useful in a variety of contexts, such as in exploratory data analysis to gain a better understanding of the data, in hypothesis testing to make inferences about a population, and in machine learning to pre-process the data and prepare it for modeling.
#
# Overall, descriptive statistics are a valuable tool for summarizing and gaining insights into data, and they are widely used in many fields including business, finance, economics, social sciences, and more.
#
#
#
# ![1_LTZmMrjHAiriMmY-XDI3yw.webp](attachment:1_LTZmMrjHAiriMmY-XDI3yw.webp)
#
#
#
#
#
# Predictive models and descriptive models are two types of statistical models used in data analysis with different purposes and applications.
#
# Predictive models are designed to make predictions about future events based on historical data. They work by learning the relationship between a set of input features and the output variable of interest through training on a labeled dataset. The goal of predictive models is to estimate the value of the output variable for new, unseen data based on the learned relationship.
#
# Examples of predictive models include linear regression, logistic regression, decision trees, random forests, and neural networks.
#
# On the other hand, descriptive models, also known as generative models, are used to describe the underlying distribution of a dataset. They summarize the relationship between variables and generate new, synthetic data that is similar to the original data. The goal of descriptive models is to gain a better understanding of the data and identify patterns in the data.
#
# Examples of descriptive models include Gaussian Mixture Models (GMM), Hidden Markov Models (HMM), Latent Dirichlet Allocation (LDA), and Autoencoders.
#
# In summary, while predictive models are used to make predictions, descriptive models are used to describe the structure and patterns in the data.

# %% [markdown]
# # 3. Describe the method of assessing a classification model's efficiency in detail. Describe the various measurement parameters.

# %% [markdown]
# Assessing the efficiency of a classification model involves evaluating its performance on a test dataset and comparing it to other models or to a baseline performance. There are several measurement parameters that are commonly used to assess the efficiency of a classification model:
#
# Accuracy: This is the most straightforward metric and it measures the fraction of correct predictions made by the model. It is calculated as the number of correct predictions divided by the total number of predictions.
#
# Confusion Matrix: A confusion matrix is a table that summarizes the performance of a classification model by showing the true positive (TP), false positive (FP), true negative (TN), and false negative (FN) predictions. The confusion matrix is useful for understanding the trade-off between precision and recall.
#
# Precision: Precision is a measure of the model's ability to make correct positive predictions. It is calculated as TP / (TP + FP).
#
# Recall (Sensitivity or True Positive Rate): Recall is a measure of the model's ability to correctly identify all positive instances. It is calculated as TP / (TP + FN).
#
# F1 Score: The F1 score is a weighted average of precision and recall, and it provides a single metric that balances both aspects of a model's performance. It is calculated as 2 * (precision * recall) / (precision + recall).
#
# Receiver Operating Characteristic (ROC) Curve: The ROC curve is a graphical representation of the relationship between the true positive rate and the false positive rate as the decision threshold is varied. The ROC curve is useful for comparing models and for choosing the best model for a particular problem.
#
# Area Under the ROC Curve (AUC): The AUC is a single number that summarizes the performance of a model over all possible thresholds. A model with an AUC of 1.0 is considered to be a perfect classifier, while a model with an AUC of 0.5 is considered to be a random classifier.
#
# These measurement parameters can be used in combination to provide a more comprehensive evaluation of a classification model's performance. The choice of which metrics to use and how to interpret the results depends on the specific problem and the goals of the analysis.
#
#
#
#
#
#
# The idea of building machine learning models works on a constructive feedback principle. You build a model, get feedback from metrics, make improvements and continue until you achieve a desirable accuracy. Evaluation metrics explain the performance of a model. An important aspect of evaluation metrics is their capability to discriminate among model results.
#
# I have seen plenty of analysts and aspiring data scientists not even bothering to check how robust their model is. Once they are finished building a model, they hurriedly map predicted values on unseen data. This is an incorrect approach.
#
# Simply building a predictive model is not your motive. It’s about creating and selecting a model which gives high accuracy on out of sample data. Hence, it is crucial to check the accuracy of your model prior to computing predicted values.
#
#
# Overview
# Evaluating a model is a core part of building an effective machine learning model
# There are several evaluation metrics in machine learning, like confusion matrix, cross-validation, AUC-ROC curve, etc.
# Different evaluation metrics for logistic regression are used for different kinds of problems
#
#
# 1.Confusion Matrix
# 2.F1 Score
# 3.Gain and Lift charts
# 4.Kolomogorov Smirnov chart
# 5.Area Under the ROC curve (AUC – ROC)
# 6.Log Loss
# 7.Gini Coefficient
# 8.Concordant – Discordant ratio
# 9.Root Mean Squared Error (RMSE)
# 10.Root Mean Squared Logarithmic Error
# 11.R-Squared/Adjusted R-Squared
# 12.Cross Validation
# Introduction
# The idea of building machine learning models works on a constructive feedback principle. You build a model, get feedback from metrics, make improvements and continue until you achieve a desirable accuracy. Evaluation metrics explain the performance of a model. An important aspect of evaluation metrics is their capability to discriminate among model results.
#
# I have seen plenty of analysts and aspiring data scientists not even bothering to check how robust their model is. Once they are finished building a model, they hurriedly map predicted values on unseen data. This is an incorrect approach.
#
# Simply building a predictive model is not your motive. It’s about creating and selecting a model which gives high accuracy on out of sample data. Hence, it is crucial to check the accuracy of your model prior to computing predicted values.
#
# machine learning, evaulation metrics
#
# In our industry, we consider different kinds of metrics to evaluate our models. The choice of metric completely depends on the type of model and the implementation plan of the model.
#
#
# After you are finished building your model, these 11 metrics will help you in evaluating your model’s accuracy. Considering the rising popularity and importance of cross-validation, I’ve also mentioned its principles in this article.
#
# And if you’re starting out your machine learning journey, you should check out the comprehensive and popular ‘Applied Machine Learning’ course which covers this concept in a lot of detail along with the various algorithms and components of machine learning.
#
# Warming up: Types of Predictive models
# When we talk about predictive models, we are talking either about a regression model (continuous output) or a classification model (nominal or binary output). The evaluation metrics used in each of these models are different.
#
# In classification problems, we use two types of algorithms (dependent on the kind of output it creates):
#
# Class output: Algorithms like SVM and KNN create a class output. For instance, in a binary classification problem, the outputs will be either 0 or 1. However, today we have algorithms which can convert these class outputs to probability. But these algorithms are not well accepted by the statistics community.
# Probability output: Algorithms like Logistic Regression, Random Forest, Gradient Boosting, Adaboost etc. give probability outputs. Converting probability outputs to class output is just a matter of creating a threshold probability.
# In regression problems, we do not have such inconsistencies in output. The output is always continuous in nature and requires no further treatment.
#
#
# 1. Confusion Matrix
# A confusion matrix is an N X N matrix, where N is the number of classes being predicted. For the problem in hand, we have N=2, and hence we get a 2 X 2 matrix. Here are a few definitions, you need to remember for a confusion matrix :
#
# Accuracy : the proportion of the total number of predictions that were correct.
# Positive Predictive Value or Precision : the proportion of positive cases that were correctly identified.
# Negative Predictive Value : the proportion of negative cases that were correctly identified.
# Sensitivity or Recall : the proportion of actual positive cases which are correctly identified.
# Specificity : the proportion of actual negative cases which are correctly identified.
#
# ![Confusion_matrix.webp](attachment:Confusion_matrix.webp)

# %% [markdown]
# ![Confusion_matrix1.webp](attachment:Confusion_matrix1.webp)

# %% [markdown]
# The accuracy for the problem in hand comes out to be 88%.  As you can see from the above two tables, the Positive predictive Value is high, but negative predictive value is quite low. Same holds for Sensitivity and Specificity. This is primarily driven by the threshold value we have chosen. If we decrease our threshold value, the two pairs of starkly different numbers will come closer.
#
# In general we are concerned with one of the above defined metric. For instance, in a pharmaceutical company, they will be more concerned with minimal wrong positive diagnosis. Hence, they will be more concerned about high Specificity. On the other hand an attrition model will be more concerned with Sensitivity. Confusion matrix are generally used only with class output models.

# %% [markdown]
# 2. F1 Score
# In the last section, we discussed precision and recall for classification problems and also highlighted the importance of choosing precision/recall basis our use case. What if for a use case, we are trying to get the best precision and recall at the same time? F1-Score is the harmonic mean of precision and recall values for a classification problem. The formula for F1-Score is as follows:
#
# ![Screenshot-2019-05-14-at-12.png](attachment:Screenshot-2019-05-14-at-12.png)
#
# Now, an obvious question that comes to mind is why are taking a harmonic mean and not an arithmetic mean. This is because HM punishes extreme values more. Let us understand this with an example. We have a binary classification model with the following results:
#
#
#
#
# Precision: 0, Recall: 1
#
# Here, if we take the arithmetic mean, we get 0.5. It is clear that the above result comes from a dumb classifier which just ignores the input and just predicts one of the classes as output. Now, if we were to take HM, we will get 0 which is accurate as this model is useless for all purposes.
#
# This seems simple. There are situations however for which a data scientist would like to give a percentage more importance/weight to either precision or recall. Altering the above expression a bit such that we can include an adjustable parameter beta for this purpose, we get:
#
#
#
# Fbeta measures the effectiveness of a model with respect to a user who attaches β times as much importance to recall as precision.

# %% [markdown]
# ![Screenshot-2019-05-14-at-1290473.png](attachment:Screenshot-2019-05-14-at-1290473.png)

# %% [markdown]
# 3. Gain and Lift charts
# Gain and Lift chart are mainly concerned to check the rank ordering of the probabilities. Here are the steps to build a Lift/Gain chart:
#
# Step 1 : Calculate probability for each observation
#
# Step 2 : Rank these probabilities in decreasing order.
#
# Step 3 : Build deciles with each group having almost 10% of the observations.
#
# Step 4 : Calculate the response rate at each deciles for Good (Responders) ,Bad (Non-responders) and total.
#
# You will get following table from which you need to plot Gain/Lift charts:
#
#
#
# ![LiftnGain.webp](attachment:LiftnGain.webp)
#
#
# This is a very informative table. Cumulative Gain chart is the graph between Cumulative %Right and Cummulative %Population. For the case in hand here is the graph :

# %% [markdown]
# ![CumGain.webp](attachment:CumGain.webp)

# %% [markdown]
# This graph tells you how well is your model segregating responders from non-responders. For example, the first decile however has 10% of the population, has 14% of responders. This means we have a 140% lift at first decile.
#
# What is the maximum lift we could have reached in first decile? From the first table of this article, we know that the total number of responders are 3850. Also the first decile will contains 543 observations. Hence, the maximum lift at first decile could have been 543/3850 ~ 14.1%. Hence, we are quite close to perfection with this model.

# %% [markdown]
# 5. Area Under the ROC curve (AUC – ROC)
# This is again one of the popular metrics used in the industry.  The biggest advantage of using ROC curve is that it is independent of the change in proportion of responders. This statement will get clearer in the following sections.
#
# Let’s first try to understand what is ROC (Receiver operating characteristic) curve. If we look at the confusion matrix below, we observe that for a probabilistic model, we get different value for each metric.
#
#
# ![Confusion_matrix%20%281%29.webp](attachment:Confusion_matrix%20%281%29.webp)
#
# Hence, for each sensitivity, we get a different specificity.The two vary as follows:

# %% [markdown]
# ![curves.webp](attachment:curves.webp)

# %% [markdown]
# The ROC curve is the plot between sensitivity and (1- specificity). (1- specificity) is also known as false positive rate and sensitivity is also known as True Positive rate. Following is the ROC curve for the case in hand.
#
#
#
# ![ROC.webp](attachment:ROC.webp)

# %% [markdown]
# Let’s take an example of threshold = 0.5 (refer to confusion matrix). Here is the confusion matrix :
#
# ![Confusion_matrix2.png](attachment:Confusion_matrix2.png)

# %% [markdown]
# As you can see, the sensitivity at this threshold is 99.6% and the (1-specificity) is ~60%. This coordinate becomes on point in our ROC curve. To bring this curve down to a single number, we find the area under this curve (AUC).
#
# Note that the area of entire square is 1*1 = 1. Hence AUC itself is the ratio under the curve and the total area. For the case in hand, we get AUC ROC as 96.4%. Following are a few thumb rules:
#
# .90-1 = excellent (A)
# .80-.90 = good (B)
# .70-.80 = fair (C)
# .60-.70 = poor (D)
# .50-.60 = fail (F)
# We see that we fall under the excellent band for the current model. But this might simply be over-fitting. In such cases it becomes very important to to in-time and out-of-time validations.
#
#
# Points to Remember:
#
# 1. For a model which gives class as output, will be represented as a single point in ROC plot.
#
# 2. Such models cannot be compared with each other as the judgement needs to be taken on a single metric and not using multiple metrics. For instance, model with parameters (0.2,0.8) and model with parameter (0.8,0.2) can be coming out of the same model, hence these metrics should not be directly compared.
#
# 3. In case of probabilistic model, we were fortunate enough to get a single number which was AUC-ROC. But still, we need to look at the entire curve to make conclusive decisions. It is also possible that one model performs better in some region and other performs better in other.
#
#
# Advantages of using ROC
# Why should you use ROC and not metrics like lift curve?
#
# Lift is dependent on total response rate of the population. Hence, if the response rate of the population changes, the same model will give a different lift chart. A solution to this concern can be true lift chart (finding the ratio of lift and perfect model lift at each decile). But such ratio rarely makes sense for the business.
#
# ROC curve on the other hand is almost independent of the response rate. This is because it has the two axis coming out from columnar calculations of confusion matrix. The numerator and denominator of both x and y axis will change on similar scale in case of response rate shift.

# %% [markdown]
# 6. Log Loss
# AUC ROC considers the predicted probabilities for determining our model’s performance. However, there is an issue with AUC ROC, it only takes into account the order of probabilities and hence it does not take into account the model’s capability to predict higher probability for samples more likely to be positive. In that case, we could us the log loss which is nothing but negative average of the log of corrected predicted probabilities for each instance.
#
#
# ![Screenshot-2019-05-14-at-1279362.png](attachment:Screenshot-2019-05-14-at-1279362.png)

# %% [markdown]
# p(yi) is predicted probability of positive class
# 1-p(yi) is predicted probability of negative class
# yi = 1 for positive class and 0 for negative class (actual values)
# Let us calculate log loss for a few random values to get the gist of the above mathematical function:
#
# Logloss(1, 0.1) = 2.303
#
# Logloss(1, 0.5) = 0.693
#
# Logloss(1, 0.9) = 0.105
#
# If we plot this relationship, we will get a curve as follows:
#
#
# ![log-loss-curve.webp](attachment:log-loss-curve.webp)

# %% [markdown]
# It’s apparent from the gentle downward slope towards the right that the Log Loss gradually declines as the predicted probability improves. Moving in the opposite direction though, the Log Loss ramps up very rapidly as the predicted probability approaches 0.
#
# So, lower the log loss, better the model. However, there is no absolute measure on a good log loss and it is use-case/application dependent.
#
# Whereas the AUC is computed with regards to binary classification with a varying decision threshold, log loss actually takes “certainty” of classification into account.

# %% [markdown]
# 7. Gini Coefficient
# Gini coefficient is sometimes used in classification problems. Gini coefficient can be straigh away derived from the AUC ROC number. Gini is nothing but ratio between area between the ROC curve and the diagnol line & the area of the above triangle. Following is the formulae used :
#
# Gini = 2*AUC – 1
#
# Gini above 60% is a good model. For the case in hand we get Gini as 92.7%.

# %% [markdown]
# 9. Root Mean Squared Error (RMSE)
# RMSE is the most popular evaluation metric used in regression problems. It follows an assumption that error are unbiased and follow a normal distribution. Here are the key points to consider on RMSE:
#
# 1.The power of ‘square root’  empowers this metric to show large number deviations.
#
# 2.The ‘squared’ nature of this metric helps to deliver more robust results which prevents cancelling the positive and negative error values. In other words, this metric aptly displays the plausible magnitude of error term.
#
# 3.It avoids the use of absolute error values which is highly undesirable in mathematical calculations.
#
# 4.When we have more samples, reconstructing the error distribution using RMSE is considered to be more reliable.
#
# 5.RMSE is highly affected by outlier values. Hence, make sure you’ve removed outliers from your data set prior to using this metric.
#
# 6.As compared to mean absolute error, RMSE gives higher weightage and punishes large errors.
#
# RMSE metric is given by:
#
# ![rmse.png](attachment:rmse.png)
#
# where, N is Total Number of Observations.

# %% [markdown]
# 10. Root Mean Squared Logarithmic Error
# In case of Root mean squared logarithmic error, we take the log of the predictions and actual values. So basically, what changes are the variance that we are measuring. RMSLE is usually used when we don’t want to penalize huge differences in the predicted and the actual values when both predicted and true values are huge numbers.
#
#
# ![Screenshot-2019-05-16-at-6.png](attachment:Screenshot-2019-05-16-at-6.png)

# %% [markdown]
# If both predicted and actual values are small: RMSE and RMSLE are same.
#
# If either predicted or the actual value is big: RMSE > RMSLE
#
# If both predicted and actual values are big: RMSE > RMSLE (RMSLE becomes almost negligible)

# %% [markdown]
# 11. R-Squared/Adjusted R-Squared
# We learned that when the RMSE decreases, the model’s performance will improve. But these values alone are not intuitive.
#
# In the case of a classification problem, if the model has an accuracy of 0.8, we could gauge how good our model is against a random model, which has an accuracy of  0.5. So the random model can be treated as a benchmark. But when we talk about the RMSE metrics, we do not have a benchmark to compare.
#
# This is where we can use R-Squared metric. The formula for R-Squared is as follows:
#
# ![Screenshot-2019-05-16-at-7.png](attachment:Screenshot-2019-05-16-at-7.png)

# %% [markdown]
# ![Screenshot-2019-05-16-at-768377.png](attachment:Screenshot-2019-05-16-at-768377.png)
#
#
# MSE(model): Mean Squared Error of the predictions against the actual values
#
# MSE(baseline): Mean Squared Error of  mean prediction against the actual values
#
# In other words how good our regression model as compared to a very simple model that just predicts the mean value of target from the train set as predictions.
#
#
#
#
#
#
# Adjusted R-Squared:-
#
#
# A model performing equal to baseline would give R-Squared as 0. Better the model, higher the r2 value. The best model with all correct predictions would give R-Squared as 1. However, on adding new features to the model, the R-Squared value either increases or remains the same. R-Squared does not penalize for adding features that add no value to the model. So an improved version over the R-Squared is the adjusted R-Squared. The formula for adjusted R-Squared is given by:

# %% [markdown]
# ![Screenshot-2019-05-16-at-710404.png](attachment:Screenshot-2019-05-16-at-710404.png)

# %% [markdown]
# k: number of features
#
# n: number of samples
#
# As you can see, this metric takes the number of features into account. When we add more features, the term in the denominator n-(k +1) decreases, so the whole expression increases.
#
# If R-Squared does not increase, that means the feature added isn’t valuable for our model. So overall we subtract a greater value from 1 and adjusted r2, in turn, would decrease.
#
# Beyond these 11 metrics, there is another method to check the model performance. These 7 methods are statistically prominent in data science. But, with arrival of machine learning, we are now blessed with more robust methods of model selection. Yes! I’m talking about Cross Validation.
#
# Though, cross validation isn’t a really an evaluation metric which is used openly to communicate model accuracy. But, the result of cross validation provides good enough intuitive result to generalize the performance of a model.
#
# Let’s now understand cross validation in detail.
#
#
#
#
# 12. Cross Validation
# Let’s first understand the importance of cross validation. Due to busy schedules, these days I don’t get much time to participate in data science competitions. Long time back, I participated in TFI Competition on Kaggle. Without delving into my competition performance, I would like to show you the dissimilarity between my public and private leaderboard score.
#
#
#
# Over-fitting is nothing but when you model become highly complex that it starts capturing noise also. This ‘noise’ adds no value to model, but only inaccuracy.
#
# In the following section, I will discuss how you can know if a solution is an over-fit or not before we actually know the test results.
#
# The concept : Cross Validation:-
#
# Cross Validation is one of the most important concepts in any type of data modelling. It simply says, try to leave a sample on which you do not train the model and test the model on this sample before finalizing the model.
#
# ![validation.png](attachment:validation.png)
#
#
#
#
#
# Above diagram shows how to validate model with in-time sample. We simply divide the population into 2 samples, and build model on one sample. Rest of the population is used for in-time validation.
#
# Could there be a negative side of the above approach?
#
# I believe, a negative side of this approach is that we loose a good amount of data from training the model. Hence, the model is very high bias. And this won’t give best estimate for the coefficients. So what’s the next best option?
#
# What if, we make a 50:50 split of training population and the train on first 50 and validate on rest 50. Then, we train on the other 50, test on first 50. This way we train the model on the entire population, however on 50% in one go. This reduces bias because of sample selection to some extent but gives a smaller sample to train the model on. This approach is known as 2-fold cross validation.

# %% [markdown]
# k-fold Cross validation :-
#
# Let’s extrapolate the last example to k-fold from 2-fold cross validation. Now, we will try to visualize how does a k-fold validation work.
#
#
# ![kfolds-150x150.png](attachment:kfolds-150x150.png)
#
#
# This is a 7-fold cross validation.
#
# Here’s what goes on behind the scene : we divide the entire population into 7 equal samples. Now we train models on 6 samples (Green boxes) and validate on 1 sample (grey box). Then, at the second iteration we train the model with a different sample held as validation. In 7 iterations, we have basically built model on each sample and held each of them as validation. This is a way to reduce the selection bias and reduce the variance in prediction power. Once we have all the 7 models, we take average of the error terms to find which of the models is best.
#
#
#
# How does this help to find best (non over-fit) model?
#
# k-fold cross validation is widely used to check whether a model is an overfit or not. If the performance metrics at each of the k times modelling are close to each other and the mean of metric is highest. In a Kaggle competition, you might rely more on the cross validation score and not on the Kaggle public score. This way you will be sure that the Public score is not just by chance.
#
#
#
# But how do we choose k?
# This is the tricky part. We have a trade off to choose k.
#
# For a small k, we have a higher selection bias but low variance in the performances.
#
# For a large k, we have a small selection bias but high variance in the performances.
#
# Think of extreme cases :
#
# k = 2  : We have only 2 samples similar to our 50-50 example. Here we build model only on 50% of the population each time. But as the validation is a significant population, the variance of validation performance is minimal.
#
# k = number of observations (n) :  This is also known as “Leave one out”. We have n samples and modelling repeated n number of times leaving only one observation out for cross validation. Hence, the selection bias is minimal but the variance of validation performance is very large.
#
# Generally a value of k = 10 is recommended for most purpose.

# %% [markdown]
# # 4. Describe the following  parts:-
# i. In the sense of machine learning models, what is underfitting? What is the most common reason for underfitting?
#
# ii. What does it mean to overfit? When is it going to happen?
#
# iii. In the sense of model fitting, explain the bias-variance trade-off.

# %% [markdown]
# i.  In the sense of machine learning models, what is underfitting? What is the most common reason for underfitting?
#
#
# Underfitting in machine learning refers to a model that does not fit the training data well enough and therefore has a poor ability to generalize to new, unseen data. It occurs when a model is too simple to capture the underlying structure of the data, resulting in high bias and low variance.
#
# The most common reason for underfitting is a model that has a limited capacity to learn the relationship between the features and the target variable. This is often the result of using a simple model or having a limited number of features or training examples. Another reason can be using a learning algorithm with a high regularization parameter, which can cause the model to under-represent the true relationship in the data.
#
#
# ![1_JzqZ0OtLqKFzsAVWYP-DBg%20%281%29.png](attachment:1_JzqZ0OtLqKFzsAVWYP-DBg%20%281%29.png)

# %% [markdown]
# ii. What does it mean to overfit? When is it going to happen?
#
# Overfitting in machine learning refers to a model that has a high capacity to fit the training data well but has poor generalization performance on new, unseen data. This occurs when a model is too complex, capturing not only the underlying structure of the data but also the noise in the training data. As a result, the model has a low bias but high variance.
#
# Overfitting is likely to occur when a model has too many features or too many model parameters, leading to a model that fits the training data too closely. It can also occur when a model has too few training examples and therefore has a limited ability to generalize to new data. Overfitting can be mitigated by using techniques such as regularization, early stopping, or ensemble methods that combine multiple models.
#
#
# iii. In the sense of model fitting, explain the bias-variance trade-off.
#
#
#
# The bias-variance trade-off is a fundamental concept in machine learning that refers to the trade-off between a model's ability to fit the training data well (low bias) and its ability to generalize well to new, unseen data (low variance).
#
# Bias refers to the error that results from making assumptions about the relationship between the features and target variable in the model. A model with high bias is likely to underfit the data, meaning that it has a poor ability to capture the underlying structure of the data.
#
# Variance refers to the error that results from a model's sensitivity to the noise or fluctuations in the training data. A model with high variance is likely to overfit the data, meaning that it has captured the noise in the training data and has a poor ability to generalize to new data.
#
# The goal in model fitting is to find a model that has a good balance between low bias and low variance, as models with high bias or high variance are likely to have poor generalization performance. Finding this balance is the key to the bias-variance trade-off.

# %% [markdown]
# # 5. Is it possible to boost the efficiency of a learning model? If so, please clarify how.

# %% [markdown]
# # Yes, it is possible to boost the efficiency of a learning model. Here are some common methods to do so:
#
# Feature Selection: Selecting the most relevant features for the model to learn from can reduce training time and improve accuracy.
#
# Hyperparameter tuning: Fine-tuning the hyperparameters of the model can improve its performance and efficiency.
#
# Regularization: Adding regularization terms to the loss function can prevent overfitting and improve the generalization ability of the model.
#
# Ensemble methods: Combining multiple models can lead to improved efficiency and accuracy.
#
# Transfer learning: Reusing pre-trained models on related tasks can save training time and improve performance.
#
# Parallel processing: Training the model on multiple processors or GPUs can speed up the training process.
#
# It's worth noting that the specific method that works best for improving the efficiency of a model depends on the problem at hand and the architecture of the model being used.

# %% [markdown]
# # 6. How would you rate an unsupervised learning model's success? What are the most common success indicators for an unsupervised learning model?

# %% [markdown]
# Evaluating the success of an unsupervised learning model is challenging, as there is no ground truth or labeled data to compare the model's outputs to. As a result, the success of an unsupervised learning model is usually evaluated based on several indirect indicators.
#
# Here are some common success indicators for unsupervised learning models:
#
# Coherence of cluster assignments: The cluster assignments made by the model should be coherent and meaningful.
#
# Separation of clusters: The clusters should be well-separated and distinct from each other.
#
# Silhouette Score: This score measures how similar an object is to its own cluster compared to other clusters. A high silhouette score is a good indicator of successful clustering.
#
# Calinski-Harabasz Index: This index measures the ratio of between-cluster variance to within-cluster variance. A high Calinski-Harabasz Index indicates good clustering.
#
# Reconstruction error: For models like autoencoders, the reconstruction error measures how well the model is able to reconstruct the input data. A low reconstruction error indicates successful training.
#
# It's worth noting that the success indicators that are most appropriate depend on the specific unsupervised learning task and the characteristics of the data being used.

# %% [markdown]
# # 7. Is it possible to use a classification model for numerical data or a regression model for categorical data with a classification model? Explain your answer.

# %% [markdown]
# Yes, it is possible to use a classification model for numerical data or a regression model for categorical data, but it's not recommended and can lead to suboptimal results.
#
# Classification models are designed to predict categorical outcomes, such as a binary label (e.g., "yes" or "no"), or multiple labels (e.g., "dog", "cat", "bird"). These models assume that the output is categorical and not continuous.
#
# On the other hand, regression models are designed to predict numerical outcomes, such as a continuous value (e.g., a price or a rating). These models assume that the output is continuous and not categorical.
#
# Therefore, using a classification model for numerical data can result in poor performance, as the model is not designed to predict continuous values. Similarly, using a regression model for categorical data can result in poor performance, as the model is not designed to predict categorical values.
#
# It's important to choose the appropriate model for the problem at hand based on the characteristics of the data and the type of outcome being predicted.

# %% [markdown]
# # 8. Describe the predictive modeling method for numerical values. What distinguishes it from categorical predictive modeling?

# %% [markdown]
# Predictive modeling for numerical values is a type of regression analysis. The goal of regression analysis is to model the relationship between a dependent variable (also known as the output or response variable) and one or more independent variables (also known as the predictors or input variables). The dependent variable is a continuous numerical value, and the independent variables can be numerical or categorical.
#
# The regression model tries to learn the relationship between the dependent variable and the independent variables by fitting a line or a more complex mathematical function to the data. The line or function represents the relationship between the independent variables and the dependent variable. Once the relationship is learned, the model can be used to make predictions for new data points.
#
# Regression models can be simple linear regression models, polynomial regression models, or more complex non-linear regression models.
#
# Categorical predictive modeling is different from regression analysis in that it is used to predict a categorical outcome, such as a binary label (e.g., "yes" or "no"), or multiple labels (e.g., "dog", "cat", "bird"). In categorical predictive modeling, the dependent variable is a categorical value and not a continuous numerical value.
#
# Categorical predictive modeling is often done using classification models, such as logistic regression, decision trees, or neural networks. These models try to learn the relationship between the independent variables and the categorical dependent variable by finding a boundary that separates the data into different classes.

# %% [markdown]
# # 9. The following data were collected when using a classification model to predict the malignancy of a group of patients' tumors:
#
# i. Accurate estimates – 15 cancerous, 75 benign.
#
# ii. Wrong predictions – 3 cancerous, 7 benign.

# %% [markdown]
# # Determine the model's error rate, Kappa value, sensitivity, precision, and F-measure.

# %% [markdown]
# To determine the error rate, kappa value, sensitivity, precision, and F-measure, we need to calculate the following values based on the given data:
#
# Total number of patients: 15 + 75 = 90
#
# True positive (TP): 15 accurate estimates of cancerous tumors.
#
# False positive (FP): 7 benign tumors predicted as cancerous.
#
# False negative (FN): 3 cancerous tumors predicted as benign.
#
# True negative (TN): 75 benign tumors predicted as benign.
#
# With these values, we can now calculate the following metrics:
#
#
# Error rate: (FP + FN) / Total = (7 + 3) / 90 = 0.1 or 10%
#
# Kappa value: (Observed accuracy - Expected accuracy) / (1 - Expected accuracy)
#
# Expected accuracy = (TP + TN) / Total * (TP + FP) / Total + (TN + FN) / Total * (TN + FN) / Total
#
# Kappa = (0.85 - 0.722) / (1 - 0.722) = 0.147
#
# Sensitivity (True positive rate or recall): TP / (TP + FN) = 15 / (15 + 3) = 0.833
#
# Precision: TP / (TP + FP) = 15 / (15 + 7) = 0.682
#
# F-measure: 2 * (Precision * Recall) / (Precision + Recall) = 2 * (0.682 * 0.833) / (0.682 + 0.833) = 0.753
#
# It's important to note that these metrics give a general overview of the performance of the model and can be influenced by factors such as class imbalance or the threshold used to make predictions.

# %% [markdown]
# # 11. Define the following terms:
# 1. Purity vs. Silhouette width
# 2. Boosting vs. Bagging
# 3. The eager learner vs. the lazy learner

# %% [markdown]
# # 1. Purity vs. Silhouette width:-

# %% [markdown]
# Purity and Silhouette width are two evaluation metrics used to assess the performance of clustering algorithms.
#
# Purity: Purity is a metric that measures the quality of the clustering by assessing how many data points in a cluster belong to the same class. It is calculated by dividing the number of data points in a cluster that belong to the same class by the total number of data points in that cluster. A higher purity value indicates a better clustering result.
#
# Silhouette width: Silhouette width is a metric that measures the similarity of each data point to its own cluster compared to other clusters. It ranges from -1 to 1, where a value close to 1 indicates that a data point is well-clustered, while a value close to -1 indicates that a data point is assigned to the wrong cluster. A higher silhouette width value indicates a better clustering result.
#
# Both metrics are commonly used to evaluate the performance of clustering algorithms, but Silhouette width is considered to be a more robust metric as it takes into account the similarity of each data point to its own cluster and to other clusters. Purity, on the other hand, only takes into account the majority class in a cluster.

# %% [markdown]
# # 2. Boosting vs. Bagging :-

# %% [markdown]
# Boosting and Bagging are two popular ensemble learning techniques used to improve the performance of machine learning models.
#
# Boosting: Boosting is an iterative technique that adjusts the weights of the instances in the training dataset to give more importance to the misclassified examples. The idea behind boosting is to train weak learners in sequence, each one trying to correct the mistakes of the previous one. Boosting algorithms include Adaboost, Gradient Boosting, and XGBoost.
#
# Bagging: Bagging (short for Bootstrapped Aggregation) is a technique that trains multiple models on different random subsets of the training data and aggregates their predictions to produce a final prediction. Unlike Boosting, Bagging does not adjust the weights of the instances and trains the models independently. Bagging algorithms include Random Forest and Extra Trees.
#
# In general, Boosting is more effective in reducing variance, while Bagging is more effective in reducing bias. Both techniques are useful in improving the performance of machine learning models, and their effectiveness depends on the specific problem and data.

# %% [markdown]
# # 3. The eager learner vs. the lazy learner :-

# %% [markdown]
# Eager Learners and Lazy Learners are two different approaches to classification in machine learning.
#
# Eager Learners: Eager Learners, also known as "instance-based learners" or "memory-based learners," build a model for classification by storing the entire training dataset in memory and comparing new instances to the stored instances to make predictions. Eager Learners are computationally expensive and perform poorly on large datasets. Examples of eager learners are the k-Nearest Neighbor (k-NN) and the Learning Vector Quantization (LVQ) algorithms.
#
# Lazy Learners: Lazy Learners, also known as "generalization-based learners," do not store the entire training dataset in memory. Instead, they only store a generalization of the training data and make predictions by computing the similarity between the new instance and the generalization. Lazy Learners are computationally efficient and perform well on large datasets, but their predictions can be slower than those of eager learners. Examples of lazy learners are the Decision Tree and the k-Nearest Neighbor (k-NN) algorithms.
#
# In general, the choice between eager and lazy learning depends on the specific problem and the size of the dataset. Eager learners are suitable for small datasets, while lazy learners are more appropriate for large datasets.
